# %% [markdown]
# # Get error distribution
#
# - Created with PtyRAD 0.1.0b12
# - Requires PtyRAD >= 0.1.0b8
# - Latest demo params files / scripts: https://github.com/chiahao3/ptyrad/tree/main/demo
# - Documentation: https://ptyrad.readthedocs.io/en/latest/
# - PtyRAD paper: https://doi.org/10.1093/mam/ozaf070
# - PtyRAD arXiv: https://arxiv.org/abs/2505.07814
# - Zenodo record: https://doi.org/10.5281/zenodo.15273176
# - Box folder: https://cornell.box.com/s/n5balzf88jixescp9l15ojx7di4xn1uo
# - Youtube channel: https://www.youtube.com/@ptyrad_official
#
# **Before running this notebook, you must first follow the instruction in `README.md` to:**
# 1. Create the Python environment with all dependant Python packages like PyTorch
# 2. Activate that python environment
# 3. Install `ptyrad` package into your activated Python environement (only need to install once)
#
# > Note: This notebook is designed for visualization of the reconstruction error.
#
# Author: Chia-Hao Lee, cl2696@cornell.edu

# %% [markdown]
# ## 00. Setup working directory and imports

# %%
import os
import numpy as np
import torch
import matplotlib.pyplot as plt

# Set this to your desired working directory so you can easily access the data, model, param files
work_dir = "H:/workspace/ptyrad/demo/"

os.chdir(work_dir)
print("Current working dir: ", os.getcwd())
# Note that the output/ directory will be automatically generated under your working directory
# Out:
# Current working dir:  H:\workspace\ptyrad\demo

# %%
from ptyrad.initialization import Initializer
from ptyrad.load import load_ptyrad, load_params
from ptyrad.models import PtychoAD
from ptyrad.reconstruction import make_batches, select_scan_indices
from ptyrad.save import save_array
from ptyrad.utils import print_system_info, set_gpu_device, CustomLogger
from ptyrad.visualization import plot_forward_pass

# %% [markdown]
# ## 01. Setup file path and parse params

# %%
model_path   = "output/tBL_WSe2/20250908_full_N16384_dp128_flipT100_random32_p6_1obj_1slice_plr1e-4_oalr5e-4_oplr5e-4_slr2e-3_orblur0.4_ozblur1.0_mamp0.03_4.0_oathr0.96_oposc_sng1.0_spr0.1/model_iter0200.hdf5"
params_path  = "output/tBL_WSe2/20250908_full_N16384_dp128_flipT100_random32_p6_1obj_1slice_plr1e-4_oalr5e-4_oplr5e-4_slr2e-3_orblur0.4_ozblur1.0_mamp0.03_4.0_oathr0.96_oposc_sng1.0_spr0.1/tBL_WSe2_reconstruct.yml"
ckpt         = load_ptyrad(model_path)
params       = load_params(params_path, validate=True)

init_params  = params.get('init_params')
model_params = params.get('model_params')
recon_params = params.get('recon_params')
# Out:
# Success! Loaded .hdf5 file as a dict from path = 'output/tBL_WSe2/20250908_full_N16384_dp128_flipT100_random32_p6_1obj_1slice_plr1e-4_oalr5e-4_oplr5e-4_slr2e-3_orblur0.4_ozblur1.0_mamp0.03_4.0_oathr0.96_oposc_sng1.0_spr0.1/model_iter0200.hdf5'
# ### Loading params file ###
# Success! Loaded .yml file path = output/tBL_WSe2/20250908_full_N16384_dp128_flipT100_random32_p6_1obj_1slice_plr1e-4_oalr5e-4_oplr5e-4_slr2e-3_orblur0.4_ozblur1.0_mamp0.03_4.0_oathr0.96_oposc_sng1.0_spr0.1/tBL_WSe2_reconstruct.yml
# validate = True: Filling defaults and validating the params file...
# Success! Params file validated and defaults applied.

# %%
# Modify the init_params so we're loading the reconstructed model
init_params['obj_source'] = 'PtyRAD'
init_params['probe_source'] = 'PtyRAD'
init_params['pos_source'] = 'PtyRAD'
init_params['obj_params'] = model_path
init_params['probe_params'] = model_path
init_params['pos_params'] = model_path

# %% [markdown]
# ## 02. Initialize logger, device, initializer, and model

# %%
logger = CustomLogger(log_file='ptyrad_log.txt', log_dir='auto', prefix_time='datetime', show_timestamp=True)

print_system_info()
device = set_gpu_device(gpuid=0) # Pass in `gpuid = None` if you don't have access to a CUDA-compatible GPU. Note that running PtyRAD with CPU would be much slower than on GPU.
init = Initializer(init_params).init_all()
model = PtychoAD(init.init_variables, model_params, device=device)
# Out:
# 2025-09-29 23:10:53,999 - ### PtyRAD Logger configuration ###
# 2025-09-29 23:10:53,999 - log_file       = 'ptyrad_log.txt'. If log_file = None, no log file will be created.
# 2025-09-29 23:10:53,999 - log_dir        = 'auto'. If log_dir = 'auto', then log will be saved to `output_path` or 'logs/'.
# 2025-09-29 23:10:53,999 - flush_file     = True. Automatically set to True if `log_file is not None`
# 2025-09-29 23:10:53,999 - prefix_time    = datetime. If true, preset strings ('date', 'time', 'datetime'), or a string of time format, a datetime str is prefixed to the `log_file`.
# 2025-09-29 23:10:53,999 - prefix_jobid   = '0'. If not 0, it'll be prefixed to the log file. This is used for hypertune mode with multiple GPUs.
# 2025-09-29 23:10:53,999 - append_to_file = True. If true, logs will be appended to the existing file. If false, the log file will be overwritten.
# 2025-09-29 23:10:53,999 - show_timestamp = True. If true, the printed information will contain a timestamp.
# 2025-09-29 23:10:54,015 -
# 2025-09-29 23:10:54,015 - ### System information ###
# 2025-09-29 23:10:54,015 - Platform: Windows-10-10.0.19045-SP0
# 2025-09-29 23:10:54,015 - Operating System: Windows 10
# 2025-09-29 23:10:54,015 - OS Version: 10.0.19045
# 2025-09-29 23:10:54,015 - Machine: AMD64
# 2025-09-29 23:10:54,015 - Processor: Intel64 Family 6 Model 85 Stepping 4, GenuineIntel
# 2025-09-29 23:10:54,015 - Available CPU cores: 12
# 2025-09-29 23:10:54,025 - Total Memory: 63.49 GB
# 2025-09-29 23:10:54,025 - Available Memory: 37.78 GB
# 2025-09-29 23:10:54,025 -
# 2025-09-29 23:10:54,025 - ### GPU information ###
# 2025-09-29 23:10:54,072 - CUDA Available: True
# 2025-09-29 23:10:54,072 - CUDA Version: 12.8
# 2025-09-29 23:10:54,087 - Available CUDA GPUs: ['Quadro P5000', 'Quadro P4000']
# 2025-09-29 23:10:54,089 - CUDA Compute Capability: ['6.1', '6.1']
# 2025-09-29 23:10:54,089 -   INFO: For torch.compile with Triton, you'll need CUDA GPU with Compute Capability >= 7.0.
# 2025-09-29 23:10:54,090 -         In addition, Triton does not directly support Windows.
# 2025-09-29 23:10:54,090 -         For Windows users, please follow the instruction and download `triton-windows` from https://github.com/woct0rdho/triton-windows.
# 2025-09-29 23:10:54,165 - MIG (Multi-Instance GPU) mode = False
# 2025-09-29 23:10:54,165 -   INFO: MIG splits a physical GPU into multiple GPU slices, but multiGPU does not support these MIG slices.
# 2025-09-29 23:10:54,165 -         In addition, multiGPU is currently only available on Linux due to the limited NCCL support.
# 2025-09-29 23:10:54,165 -       -> If you're doing normal reconstruction/hypertune, you can safely ignore this.
# 2025-09-29 23:10:54,165 -       -> If you want to do multiGPU, you must provide multiple 'full' GPUs that are not in MIG mode.
# 2025-09-29 23:10:54,165 -
# 2025-09-29 23:10:54,165 - ### Python information ###
# 2025-09-29 23:10:54,165 - Python Executable: c:\Users\chiahao3\miniforge3\envs\ptyrad\python.exe
# 2025-09-29 23:10:54,165 - Python Version: 3.12.11 | packaged by Anaconda, Inc. | (main, Jun  5 2025, 12:58:53) [MSC v.1929 64 bit (AMD64)]
# 2025-09-29 23:10:54,165 -
# 2025-09-29 23:10:54,165 - ### Packages information ###
# 2025-09-29 23:10:54,184 - Numpy Version (metadata): 2.1.2
# 2025-09-29 23:10:54,184 - PyTorch Version (metadata): 2.7.1+cu128
# 2025-09-29 23:10:54,184 - Optuna Version (metadata): 4.4.0
# 2025-09-29 23:10:54,184 - Accelerate Version (metadata): 1.9.0
# 2025-09-29 23:10:54,199 - PtyRAD Version (ptyrad/__init__.py): 0.1.0b11
# 2025-09-29 23:10:54,199 - PtyRAD is located at: \\altas.cac.cornell.edu\cl2696\workspace\ptyrad\src\ptyrad\__init__.py
# 2025-09-29 23:10:54,199 -
# 2025-09-29 23:10:54,199 - ### Setting GPU Device ###
# 2025-09-29 23:10:54,199 - Selected GPU device: cuda:0 (Quadro P5000)
# 2025-09-29 23:10:54,199 -
# 2025-09-29 23:10:54,199 - init_params are displayed below:
# 2025-09-29 23:10:54,199 -   random_seed: None
# 2025-09-29 23:10:54,199 -   probe_illum_type: electron
# 2025-09-29 23:10:54,199 -   probe_kv: 80.0
# 2025-09-29 23:10:54,199 -   probe_conv_angle: 24.9
# 2025-09-29 23:10:54,211 -   probe_defocus: 0.0
# 2025-09-29 23:10:54,211 -   probe_c3: 0.0
# 2025-09-29 23:10:54,212 -   probe_c5: 0.0
# 2025-09-29 23:10:54,212 -   beam_kev: None
# 2025-09-29 23:10:54,212 -   probe_dRn: None
# 2025-09-29 23:10:54,212 -   probe_Rn: None
# 2025-09-29 23:10:54,212 -   probe_D_H: None
# 2025-09-29 23:10:54,212 -   probe_D_FZP: None
# 2025-09-29 23:10:54,212 -   probe_Ls: None
# 2025-09-29 23:10:54,212 -   meas_Npix: 128
# 2025-09-29 23:10:54,212 -   pos_N_scans: 16384
# 2025-09-29 23:10:54,212 -   pos_N_scan_slow: 128
# 2025-09-29 23:10:54,212 -   pos_N_scan_fast: 128
# 2025-09-29 23:10:54,212 -   pos_scan_step_size: 0.429
# 2025-09-29 23:10:54,212 -   meas_calibration: {'mode': 'fitRBF', 'value': None}
# 2025-09-29 23:10:54,212 -   probe_pmode_max: 6
# 2025-09-29 23:10:54,212 -   probe_pmode_init_pows: [0.02]
# 2025-09-29 23:10:54,212 -   obj_omode_max: 1
# 2025-09-29 23:10:54,212 -   obj_omode_init_occu: {'occu_type': 'uniform', 'init_occu': None}
# 2025-09-29 23:10:54,212 -   obj_Nlayer: 1
# 2025-09-29 23:10:54,212 -   obj_slice_thickness: 12.0
# 2025-09-29 23:10:54,227 -   meas_permute: None
# 2025-09-29 23:10:54,227 -   meas_reshape: None
# 2025-09-29 23:10:54,227 -   meas_flipT: [1, 0, 0]
# 2025-09-29 23:10:54,227 -   meas_crop: None
# 2025-09-29 23:10:54,227 -   meas_pad: {'mode': None, 'padding_type': 'power', 'target_Npix': 256, 'value': 0.0, 'threshold': 70}
# 2025-09-29 23:10:54,227 -   meas_resample: {'mode': None, 'scale_factors': [2.0, 2.0]}
# 2025-09-29 23:10:54,227 -   meas_add_source_size: None
# 2025-09-29 23:10:54,227 -   meas_add_detector_blur: None
# 2025-09-29 23:10:54,227 -   meas_remove_neg_values: {'mode': 'clip_neg', 'value': None, 'force': False}
# 2025-09-29 23:10:54,227 -   meas_normalization: {'mode': 'max_at_one', 'value': None}
# 2025-09-29 23:10:54,227 -   meas_add_poisson_noise: None
# 2025-09-29 23:10:54,227 -   meas_export: None
# 2025-09-29 23:10:54,227 -   probe_permute: None
# 2025-09-29 23:10:54,227 -   probe_z_shift: None
# 2025-09-29 23:10:54,227 -   pos_scan_flipT: None
# 2025-09-29 23:10:54,227 -   pos_scan_affine: None
# 2025-09-29 23:10:54,227 -   pos_scan_rand_std: 0.15
# 2025-09-29 23:10:54,242 -   obj_z_crop: None
# 2025-09-29 23:10:54,244 -   obj_z_pad: None
# 2025-09-29 23:10:54,245 -   obj_z_resample: None
# 2025-09-29 23:10:54,245 -   meas_source: file
# 2025-09-29 23:10:54,246 -   meas_params: {'path': 'data\\tBL_WSe2\\Panel_g-h_Themis\\scan_x128_y128.raw', 'key': None, 'shape': None, 'offset': None, 'gap': None}
# 2025-09-29 23:10:54,247 -   probe_source: PtyRAD
# 2025-09-29 23:10:54,247 -   probe_params: output/tBL_WSe2/20250908_full_N16384_dp128_flipT100_random32_p6_1obj_1slice_plr1e-4_oalr5e-4_oplr5e-4_slr2e-3_orblur0.4_ozblur1.0_mamp0.03_4.0_oathr0.96_oposc_sng1.0_spr0.1/model_iter0200.hdf5
# 2025-09-29 23:10:54,248 -   pos_source: PtyRAD
# 2025-09-29 23:10:54,250 -   pos_params: output/tBL_WSe2/20250908_full_N16384_dp128_flipT100_random32_p6_1obj_1slice_plr1e-4_oalr5e-4_oplr5e-4_slr2e-3_orblur0.4_ozblur1.0_mamp0.03_4.0_oathr0.96_oposc_sng1.0_spr0.1/model_iter0200.hdf5
# 2025-09-29 23:10:54,250 -   obj_source: PtyRAD
# 2025-09-29 23:10:54,250 -   obj_params: output/tBL_WSe2/20250908_full_N16384_dp128_flipT100_random32_p6_1obj_1slice_plr1e-4_oalr5e-4_oplr5e-4_slr2e-3_orblur0.4_ozblur1.0_mamp0.03_4.0_oathr0.96_oposc_sng1.0_spr0.1/model_iter0200.hdf5
# 2025-09-29 23:10:54,250 -   tilt_source: simu
# 2025-09-29 23:10:54,250 -   tilt_params: {'tilt_type': 'all', 'init_tilts': [[0.0, 0.0]]}
# 2025-09-29 23:10:54,250 -
# 2025-09-29 23:10:54,250 - ### Initializing cache ###
# 2025-09-29 23:10:54,250 - Loading 'PtyRAD' file from output/tBL_WSe2/20250908_full_N16384_dp128_flipT100_random32_p6_1obj_1slice_plr1e-4_oalr5e-4_oplr5e-4_slr2e-3_orblur0.4_ozblur1.0_mamp0.03_4.0_oathr0.96_oposc_sng1.0_spr0.1/model_iter0200.hdf5 for caching
# 2025-09-29 23:10:54,373 - Success! Loaded .hdf5 file as a dict from path = 'output/tBL_WSe2/20250908_full_N16384_dp128_flipT100_random32_p6_1obj_1slice_plr1e-4_oalr5e-4_oplr5e-4_slr2e-3_orblur0.4_ozblur1.0_mamp0.03_4.0_oathr0.96_oposc_sng1.0_spr0.1/model_iter0200.hdf5'
# 2025-09-29 23:10:54,375 - use_cached_obj   = True
# 2025-09-29 23:10:54,376 - use_cached_probe = True
# 2025-09-29 23:10:54,377 - use_cached_pos   = True
# 2025-09-29 23:10:54,378 -
# 2025-09-29 23:10:54,379 - ### Initializing measurements ###
# 2025-09-29 23:10:54,380 - Loading measurements from source = 'file'
# 2025-09-29 23:10:54,381 - Detected measurement file type = '.raw'
# 2025-09-29 23:10:54,382 - WARNING: Couldn't find the 'shape' in 'meas_params' with file type = '.raw'.
# 2025-09-29 23:10:54,383 - It is strongly recommended to provide an explicit shape to better load from .raw files
# 2025-09-29 23:10:54,383 - PtyRAD will still try to load the dataset based on the provided 'init_params', but you may consider setting 'shape': (N_scans, Npix, Npix) inside your 'meas_params' dict.
# 2025-09-29 23:11:04,352 - Success! Loaded .raw file path = data\tBL_WSe2\Panel_g-h_Themis\scan_x128_y128.raw
# 2025-09-29 23:11:04,352 - Imported .raw data shape = (16384, 128, 128)
# 2025-09-29 23:11:04,352 - Imported .raw data type = float32
# 2025-09-29 23:11:04,806 - Casting measurements dtype to float32 (single precision) for computational efficiency.
# 2025-09-29 23:11:04,811 - Imported meausrements shape / dtype = (16384, 128, 128), dtype = float32
# 2025-09-29 23:11:05,228 - Imported meausrements int. statistics (min, mean, max) = (-30.8785, 1814.7064, 99441.8047)
# 2025-09-29 23:11:05,228 - Flipping measurements with [flipud, fliplr, transpose] = [1, 0, 0]
# 2025-09-29 23:11:06,103 - Removing negative values in measurement with method = clip_neg and value = None
# 2025-09-29 23:11:06,242 - Minimum value = -30.8785, negative values are clipped to 0 due to the positive px value constraint of measurements
# 2025-09-29 23:11:08,611 - Normalizing measurements with mode = 'max_at_one' and value = 'None'
# 2025-09-29 23:11:09,211 - Normalizing by max of the 2D mean pattern intensity: 67097.391
# 2025-09-29 23:11:10,431 - meausrements int. statistics (min, mean, max) = (0.0000, 0.0271, 1.4821)
# 2025-09-29 23:11:10,633 - No negative values found in measurements. Skipping non-neg correction.
# 2025-09-29 23:11:11,296 - meausrements int. statistics (min, mean, max) = (0.0000, 0.0271, 1.4821)
# 2025-09-29 23:11:11,296 - measurements                      (N, Ky, Kx) = float32, (16384, 128, 128)
# 2025-09-29 23:11:11,296 -
# 2025-09-29 23:11:11,296 - ### Setting up calibration ###
# 2025-09-29 23:11:11,296 - meas_calibration mode = 'fitRBF', value = None
# 2025-09-29 23:11:11,296 - Using loaded raw averaged measurement (before crop/pad/resample) to fit RBF as a part of the meas calibration
# 2025-09-29 23:11:11,296 - Radius of fitted bright field disk (RBF) = 11.64 px with Npix = 128
# 2025-09-29 23:11:11,304 - Suggested probe_mask_k radius (RBF*2/Npix) > 0.1819
# 2025-09-29 23:11:11,304 - Fitting raw averaged measurement with center, radius, and Gaussian blur std as a sanity check
# 2025-09-29 23:11:11,304 - Note that the fitted Gaussian blur std (detector blur) would be affected by overlapping Bragg disks
# 2025-09-29 23:11:11,304 - Initial guess: center=(63.78, 63.93), radius=11.64, Gaussian blur std=0.50
# 2025-09-29 23:11:11,320 - Final fit: center=(63.78, 63.93), radius=11.64, Gaussian blur std=0.54
# 2025-09-29 23:11:11,320 - WARNING: The 'fitRBF' and 'RBF' calibration methods are highly dependent on the accuracy of user-provided experimental parameters and acquisition conditions,
# 2025-09-29 23:11:11,320 -          including convergence angle, kV, dose, specimen thickness, and collection angle for the estimation of RBF.
# 2025-09-29 23:11:11,320 -          For example, a 5-10% error in convergence angle is fairly common.
# 2025-09-29 23:11:11,320 -          Users are strongly advised to perform proper microscope calibration to ensure accurate results.
# 2025-09-29 23:11:11,320 -          These method should only be used as a rough estimate and not as a substitute for proper experimental calibration.
# 2025-09-29 23:11:11,320 - dx (real space pixel size of probe and object) set to 0.1526 Ang with Npix = 128
# 2025-09-29 23:11:11,320 -
# 2025-09-29 23:11:11,320 - ### Setting init_variables dict ###
# 2025-09-29 23:11:11,320 - Derived values given input init_params:
# 2025-09-29 23:11:11,320 -   kv          = 80.0 kV
# 2025-09-29 23:11:11,320 -   wavelength  = 0.0418 Ang
# 2025-09-29 23:11:11,320 -   conv_angle  = 24.9 mrad
# 2025-09-29 23:11:11,320 -   Npix        = 128 px
# 2025-09-29 23:11:11,320 -   dk          = 0.0512 Ang^-1
# 2025-09-29 23:11:11,320 -   kMax        = 3.2773 Ang^-1
# 2025-09-29 23:11:11,320 -   da          = 2.1383 mrad
# 2025-09-29 23:11:11,336 -   angleMax    = 136.8515 mrad
# 2025-09-29 23:11:11,336 -   RBF         = 11.6447 px (Inferred from the given calibration, NOT necessarily from the loaded measurement data)
# 2025-09-29 23:11:11,336 -   n_alpha     = 5.4960 (# conv_angle)
# 2025-09-29 23:11:11,336 -   dx          = 0.1526 Ang, Nyquist-limited dmin = 2*dx = 0.3051 Ang
# 2025-09-29 23:11:11,336 -   Rayleigh-limited resolution  = 1.0230 Ang (0.61*lambda/alpha for focused probe )
# 2025-09-29 23:11:11,336 -   Real space probe extent = 19.5282 Ang
# 2025-09-29 23:11:11,336 -
# 2025-09-29 23:11:11,336 - ### Initializing probe ###
# 2025-09-29 23:11:11,336 - Loading probe from source = 'PtyRAD'
# 2025-09-29 23:11:11,336 - Loaded probe shape = (6, 128, 128), dtype = complex64
# 2025-09-29 23:11:11,336 - pmode_now: 6 and pmode_max: 6, leaving the pmode unchanged.
# 2025-09-29 23:11:11,336 - Orthogonalizing 6 pmodes
# 2025-09-29 23:11:11,336 - Sorting 6 pmodes by their intensities
# 2025-09-29 23:11:11,351 - sum(|probe_data|**2) = 443.31, while meas.mean(0).sum() = 443.31
# 2025-09-29 23:11:11,351 - probe                         (pmode, Ny, Nx) = complex64, (6, 128, 128)
# 2025-09-29 23:11:11,351 -
# 2025-09-29 23:11:11,351 - ### Initializing probe positions ###
# 2025-09-29 23:11:11,351 - Loading probe positions from source = 'PtyRAD'
# 2025-09-29 23:11:11,351 - Applying Gaussian distributed random displacement with std = 0.15 px to scan positions
# 2025-09-29 23:11:11,351 - crop_pos                                (N,2) = int16, (16384, 2)
# 2025-09-29 23:11:11,351 - crop_pos 1st and last px coords (y,x)         = ([50, 52], [404, 403])
# 2025-09-29 23:11:11,351 - crop_pos extent (Ang)                         = [54.61784175 55.22809696]
# 2025-09-29 23:11:11,351 - probe_pos_shifts                        (N,2) = float32, (16384, 2)
# 2025-09-29 23:11:11,351 -
# 2025-09-29 23:11:11,351 - ### Initializing object ###
# 2025-09-29 23:11:11,367 - Loading object from source = 'PtyRAD'
# 2025-09-29 23:11:11,386 - omode_now: 1 and omode_max: 1, leaving the omode unchanged.
# 2025-09-29 23:11:11,386 - object                    (omode, Nz, Ny, Nx) = complex64, (1, 1, 583, 583)
# 2025-09-29 23:11:11,398 - object extent                 (Z, Y, X) (Ang) = [12.     88.9447 88.9447]
# 2025-09-29 23:11:11,398 -
# 2025-09-29 23:11:11,398 - ### Initializing omode_occu from 'uniform' ###
# 2025-09-29 23:11:11,398 - omode_occu                            (omode) = float32, (1,)
# 2025-09-29 23:11:11,398 -
# 2025-09-29 23:11:11,406 - ### Initializing H (Fresnel propagator) ###
# 2025-09-29 23:11:11,407 - Calculating H with probe_shape = [128. 128.] px, dx = 0.1526 Ang, slice_thickness = 12.0000 Ang, lambd = 0.0418 Ang
# 2025-09-29 23:11:11,411 - H                                    (Ky, Kx) = complex64, (128, 128)
# 2025-09-29 23:11:11,412 -
# 2025-09-29 23:11:11,413 - ### Initializing obj tilts from = 'simu' ###
# 2025-09-29 23:11:11,414 - Initialized obj_tilts with init_tilts = [[0.0, 0.0]] (theta_y, theta_x) mrad
# 2025-09-29 23:11:11,415 - obj_tilts                              (N, 2) = float32, (1, 2)
# 2025-09-29 23:11:11,416 -
# 2025-09-29 23:11:11,416 - ### Checking consistency between input params with the initialized variables ###
# 2025-09-29 23:11:11,417 - Npix, DP measurements, probe, and H shapes are consistent as '128'
# 2025-09-29 23:11:11,420 - N_scans, len(meas), N_scan_slow*N_scan_fast, len(crop_pos), and len(probe_pos_shifts) are consistent as '16384'
# 2025-09-29 23:11:11,421 - obj.shape[0] is consistent with len(omode_occu) as '1'
# 2025-09-29 23:11:11,422 - obj.shape[1] is consistent with Nlayer as '1'
# 2025-09-29 23:11:11,426 - crop positions (yx_min=[49 47], yx_max=[535 537]) are well contained inside object canvas (Ny,Nx) = (583, 583).
# 2025-09-29 23:11:11,427 - obj_tilts is consistent with either 1 or N_scans
# 2025-09-29 23:11:11,429 - Pass the consistency check of initialized variables, initialization is done!
# 2025-09-29 23:11:11,432 - ### Initializing PtychoAD model ###
# 2025-09-29 23:11:12,452 - ### PtychoAD optimizable variables ###
# 2025-09-29 23:11:12,454 - obja            : torch.Size([1, 1, 583, 583])    , torch.float32   , device:cuda:0, grad:True , lr:5e-04
# 2025-09-29 23:11:12,454 - objp            : torch.Size([1, 1, 583, 583])    , torch.float32   , device:cuda:0, grad:True , lr:5e-04
# 2025-09-29 23:11:12,455 - obj_tilts       : torch.Size([1, 2])              , torch.float32   , device:cuda:0, grad:False, lr:0e+00
# 2025-09-29 23:11:12,456 - slice_thickness : torch.Size([])                  , torch.float32   , device:cuda:0, grad:False, lr:0e+00
# 2025-09-29 23:11:12,457 - probe           : torch.Size([6, 128, 128, 2])    , torch.float32   , device:cuda:0, grad:True , lr:1e-04
# 2025-09-29 23:11:12,458 - probe_pos_shifts: torch.Size([16384, 2])          , torch.float32   , device:cuda:0, grad:True , lr:2e-03
# 2025-09-29 23:11:12,458 -
# 2025-09-29 23:11:12,459 - ### Optimizable variables statitsics ###
# 2025-09-29 23:11:12,461 - Total measurement values  : 268,435,456
# 2025-09-29 23:11:12,462 - Total optimizing variables: 909,154
# 2025-09-29 23:11:12,462 - Overdetermined ratio      : 295.26
# 2025-09-29 23:11:12,462 -
# 2025-09-29 23:11:12,462 - ### Model behavior ###
# 2025-09-29 23:11:12,462 - Obj preblur               : False
# 2025-09-29 23:11:12,462 - Tilt propagator           : False
# 2025-09-29 23:11:12,462 - Change slice thickness    : False
# 2025-09-29 23:11:12,462 - Sub-px probe shift        : True
# 2025-09-29 23:11:12,462 - Detector blur             : False
# 2025-09-29 23:11:12,462 - On-the-fly meas padding   : False
# 2025-09-29 23:11:12,462 - On-the-fly meas resample  : False
# 2025-09-29 23:11:12,462 -
# 2025-09-29 23:11:12,492 - ### Done initializing PtychoAD model ###
# 2025-09-29 23:11:12,492 -

# %%
# Run a forward pass to check if the reconstructed model (obj, probe, pos) was correctly loaded
indices = np.random.randint(0, init.init_variables["N_scans"], 2)
dp_power = 0.5
plot_forward_pass(model, indices, dp_power)

# %% [markdown]
# ## 03. Run 1 full foward pass for the error distribution

# %%
INDICES_MODE      = recon_params.get('INDICES_MODE')
batch_config      = recon_params.get('BATCH_SIZE', {})
grad_accumulation = batch_config.get("grad_accumulation", 1)
batch_size        = batch_config.get('size') * grad_accumulation
GROUP_MODE        = recon_params.get('GROUP_MODE')

pos = (model.crop_pos + model.opt_probe_pos_shifts).detach().cpu().numpy()

indices = select_scan_indices(
    init.init_variables['N_scan_slow'],
    init.init_variables['N_scan_fast'],
    subscan_slow=INDICES_MODE.get('subscan_slow'),
    subscan_fast=INDICES_MODE.get('subscan_fast'),
    mode=INDICES_MODE.get('mode', 'random'),
)

batches = make_batches(indices, pos, batch_size, mode=GROUP_MODE)
# Out:
# 2025-09-29 23:11:15,134 - Selecting indices with the 'full' mode
# 2025-09-29 23:11:16,541 - Generated 512 'random' groups of ~32 scan positions in 0.016 sec

# %%
# Initialize error_DP to hold the relative error patterns, note that this would take the same amount of GPU VRAM as the 4D-dataset

Npix = model.get_complex_probe_view().shape[-1]
error_DP = torch.zeros((len(indices), Npix, Npix), device=device, dtype=torch.float32)

# %%
dp_pow = 0.5

for batch in batches:
    with torch.no_grad():
        model_DP = model(batch)
        measured_DP = model.get_measurements(batch)
        data_mean   = measured_DP.pow(dp_pow).mean(0).clamp(min=1e-8)
        error_DP[batch] = (model_DP.pow(dp_pow) - measured_DP.pow(dp_pow)) / data_mean # error_DP corresponds to the relative error

# %%
error_DP_arr = error_DP.detach().cpu().numpy()

# Saving is optional but you can port it into py4DGUI for interactive visualization
save_array(error_DP_arr, file_dir='./', file_name='relative_error', file_format="hdf5", output_shape=None, append_shape=True,)
# Out:
# 2025-09-29 23:11:19,623 - Saving array with shape = (16384, 128, 128) and dtype = float32
# 2025-09-29 23:11:19,638 - file path = './relative_error_16384_128_128.hdf5' already exists, the file will be overwritten.
# 2025-09-29 23:12:23,149 - Success! Saved data as 'meas' to .hdf5 file: ./relative_error_16384_128_128.hdf5

# %%
N_scan_slow = init.init_variables['N_scan_slow']
N_scan_fast = init.init_variables['N_scan_fast']

fig, axs = plt.subplots(nrows=1,ncols=2, figsize = (12,6))
axs[0].set_title('Fourier Space Error Distribution')
im0 = axs[0].imshow(error_DP_arr.mean(0), cmap='seismic', vmin=-0.2, vmax=0.2)
fig.colorbar(im0, shrink=0.6)

axs[1].set_title('Real Space Error Distribution')
im1 = axs[1].imshow(error_DP_arr.mean((-1,-2)).reshape(N_scan_slow, N_scan_fast), cmap='seismic', vmin=-0.2, vmax=0.2)
fig.colorbar(im1, shrink=0.6)
plt.show()

# %% [markdown]
# ## Note
# - Since it's relative error, it naturally contains positive and negative values for each error_DP (N, ky, kx)
# - If we take the average along N, then inevitably some k pixels would have their errors cancel out.
# - Similarly, when we average along (ky, kx), errors for all k pixels would be averaged together and show an overall trend for each probe position.
#
# ## Fourier Space Error Distribution
# - Low k region (center) shows low relative error, which is more or less expected as it contains most of the signal and generally SNR ~ 1/sqrt(signal)
# - High k region has higher relative error, indicating model DP predicts stronger intensity than experiment pattern.
#
# ## Real Space Error Distribution
# - On atomic sites the relative error tend to be negative values, indicating model DP predicts overall lower intensity than experiment pattern.
